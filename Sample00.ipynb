# %% [markdown]
# # Syntax example

# %%
translations = [(12*x, 10*y)
                for x in range(-5, 5)
                for y in range(-5, 5)]

# %%
print(translations)
# Out:
# [(-60, -50), (-60, -40), (-60, -30), (-60, -20), (-60, -10), (-60, 0), (-60, 10), (-60, 20), (-60, 30), (-60, 40), (-48, -50), (-48, -40), (-48, -30), (-48, -20), (-48, -10), (-48, 0), (-48, 10), (-48, 20), (-48, 30), (-48, 40), (-36, -50), (-36, -40), (-36, -30), (-36, -20), (-36, -10), (-36, 0), (-36, 10), (-36, 20), (-36, 30), (-36, 40), (-24, -50), (-24, -40), (-24, -30), (-24, -20), (-24, -10), (-24, 0), (-24, 10), (-24, 20), (-24, 30), (-24, 40), (-12, -50), (-12, -40), (-12, -30), (-12, -20), (-12, -10), (-12, 0), (-12, 10), (-12, 20), (-12, 30), (-12, 40), (0, -50), (0, -40), (0, -30), (0, -20), (0, -10), (0, 0), (0, 10), (0, 20), (0, 30), (0, 40), (12, -50), (12, -40), (12, -30), (12, -20), (12, -10), (12, 0), (12, 10), (12, 20), (12, 30), (12, 40), (24, -50), (24, -40), (24, -30), (24, -20), (24, -10), (24, 0), (24, 10), (24, 20), (24, 30), (24, 40), (36, -50), (36, -40), (36, -30), (36, -20), (36, -10), (36, 0), (36, 10), (36, 20), (36, 30), (36, 40), (48, -50), (48, -40),
# ...
